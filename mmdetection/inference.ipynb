# %%
from mmdet.apis import init_detector, inference_detector, show_result_pyplot
import mmcv
from tqdm import tqdm
from glob import glob
import numpy as np
import pandas as pd

# %%
config_file = 'configs/lesion/faster_rcnn_r50_fpn_1x_coco.py'
checkpoint_file = '/home/minyong-voyagerx/Mignon/Min/bb-detection/mmdetection/work_dirs/baseline_faster-rcnn/epoch_7.pth'

# build the model from a config file and a checkpoint file
model = init_detector(config_file, checkpoint_file, device='cuda:0')

# test a single image and show the results
img = '../data/test/test_205629.jpg'  # or img = mmcv.imread(img), which will only load it once
result = inference_detector(model, img)

# visualize the results in a new window
show_result_pyplot(model, img, result, score_thr=0.5)

# or save the visualization results to image files
# show_result_pyplot(img, result, model.CLASSES, out_file='result.jpg')
# Out:
# load checkpoint from local path: /home/minyong-voyagerx/Mignon/Min/bb-detection/mmdetection/work_dirs/baseline_faster-rcnn/epoch_7.pth
